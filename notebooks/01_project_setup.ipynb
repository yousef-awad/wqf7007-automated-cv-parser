# %% [markdown]
# # Automated CV Parser for Structured Detail Extraction
#
# WQF7007 group project workspace.

# %% [markdown]
# ## Current Objective
#
# Prepare the project pitch and set up the repository for collaboration.

# %% [markdown]
# ## Research Notes
#
# - Selected primary dataset: `yashpwr/resume-ner-training-data`
# - Extraction targets: job titles, technical skills, educational background
# - Baseline direction: BERT-based token classification for resume NER

# %%
project = {
    'title': 'Automated CV Parser for Structured Detail Extraction',
    'team_role': 'Data Engineer',
    'targets': ['job_titles', 'skills', 'education']
}
project

# %%
from datasets import load_dataset

dataset = load_dataset("yashpwr/resume-ner-training-data")
dataset

# %%
# Placeholder for future data preprocessing steps.
